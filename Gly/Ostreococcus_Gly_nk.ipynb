# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#SBML-model-ostreococcus" data-toc-modified-id="SBML-model-ostreococcus-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>SBML model ostreococcus</a></div><div class="lev2 toc-item"><a href="#Deadly-sbml-file-downloaded-form-PT" data-toc-modified-id="Deadly-sbml-file-downloaded-form-PT-11"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Deadly sbml file downloaded form PT</a></div><div class="lev1 toc-item"><a href="#Otauri-Models-from-Pathway-tools" data-toc-modified-id="Otauri-Models-from-Pathway-tools-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Otauri Models from Pathway tools</a></div><div class="lev2 toc-item"><a href="#conversion-from-SBML-to-Boltzmann-input-files" data-toc-modified-id="conversion-from-SBML-to-Boltzmann-input-files-21"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>conversion from SBML to Boltzmann input files</a></div><div class="lev2 toc-item"><a href="#Centeral-Metabolism-Rxn-for-MetaFlux-in-PT" data-toc-modified-id="Centeral-Metabolism-Rxn-for-MetaFlux-in-PT-22"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Centeral Metabolism Rxn for MetaFlux in PT</a></div><div class="lev2 toc-item"><a href="#Get-Chemical-Potential" data-toc-modified-id="Get-Chemical-Potential-23"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Get Chemical Potential</a></div><div class="lev1 toc-item"><a href="#Boltzmann" data-toc-modified-id="Boltzmann-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Boltzmann</a></div><div class="lev2 toc-item"><a href="#Pentose-phosphate-+-Glycolysis-+-TCA-cycle-+-Photosynthesis" data-toc-modified-id="Pentose-phosphate-+-Glycolysis-+-TCA-cycle-+-Photosynthesis-31"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Pentose phosphate + Glycolysis + TCA cycle + Photosynthesis</a></div><div class="lev2 toc-item"><a href="#Regulation" data-toc-modified-id="Regulation-32"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Regulation</a></div><div class="lev1 toc-item"><a href="#Analyze-Simulation-Results-for-centeral-Metabolism" data-toc-modified-id="Analyze-Simulation-Results-for-centeral-Metabolism-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Analyze Simulation Results for centeral Metabolism</a></div><div class="lev2 toc-item"><a href="#Likelihoods-from-Deterministic-Simulation" data-toc-modified-id="Likelihoods-from-Deterministic-Simulation-41"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Likelihoods from Deterministic Simulation</a></div><div class="lev2 toc-item"><a href="#Likelihoods-from-Stochastic-Simulation" data-toc-modified-id="Likelihoods-from-Stochastic-Simulation-42"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Likelihoods from Stochastic Simulation</a></div><div class="lev2 toc-item"><a href="#Read-in-Flux-Values-from-Stochastic-Simulation" data-toc-modified-id="Read-in-Flux-Values-from-Stochastic-Simulation-43"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Read in Flux Values from Stochastic Simulation</a></div><div class="lev2 toc-item"><a href="#Analyze-Metabolite-Levels-from-Deterministic-Simulation" data-toc-modified-id="Analyze-Metabolite-Levels-from-Deterministic-Simulation-44"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Analyze Metabolite Levels from Deterministic Simulation</a></div><div class="lev2 toc-item"><a href="#Analyze-Metabolite-Levels-from-Stochastic-Simulation" data-toc-modified-id="Analyze-Metabolite-Levels-from-Stochastic-Simulation-45"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Analyze Metabolite Levels from Stochastic Simulation</a></div><div class="lev2 toc-item"><a href="#Compare-ODE-and-Stochastic-Metabolite-Concentrations" data-toc-modified-id="Compare-ODE-and-Stochastic-Metabolite-Concentrations-46"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Compare ODE and Stochastic Metabolite Concentrations</a></div><div class="lev2 toc-item"><a href="#Display-Pathway-Predictions" data-toc-modified-id="Display-Pathway-Predictions-47"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Display Pathway Predictions</a></div><div class="lev1 toc-item"><a href="#Infer-Regulated-Reactions" data-toc-modified-id="Infer-Regulated-Reactions-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Infer Regulated Reactions</a></div>

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import subprocess
import re
import os
import mentos
from IPython.core.display import display
#from ipynb_latex_setup import *
# %matplotlib inline
import cobra
#%matplotlib pdf
#matplotlib.matplotlib_fname()
#import matplotlib.rcsetup as rcsetup
#print(rcsetup.all_backends)

# %% [markdown]
# # SBML model ostreococcus

# %%
import json
import os
import cobra
modeldir = '/Users/kuma889/Projects/Boltzmann/Boltz/Ostreococcus/SBML'
full_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'Libourel_Otauri_SBMLModel.xml'))
#core_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'Otauri.COBRA-sbml3.xml'))
full_model.optimize()
# Out:
# -----
# UnicodeEncodeErrorTraceback (most recent call last)
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     336             method = get_real_method(obj, self.print_method)
#     337             if method is not None:
# --> 338                 return method()
#     339             return None
#     340         else:
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/cobra/core/solution.pyc in _repr_html_(self)
#      94                         'value {:.3f}</strong><br>{}'
#      95                         .format(self.objective_value,
# ---> 96                                 self.to_frame()._repr_html_()))
#      97         else:
#      98             html = '<strong><em>{}</em> solution</strong>'.format(self.status)
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\xd7' in position 1382: ordinal not in range(128)
# <Solution 0.275 at 0x118b7f4d0>

# %% [markdown]
# ## Deadly sbml file downloaded form PT

# %%
modeldir = '/Users/kuma889/Projects/Boltzmann/Boltz/Ostreococcus/SBML'
#core_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'Libourel_Otauri_SBMLModel.xml'))
fulla_model_from_PT = cobra.io.read_sbml_model(os.path.join(modeldir, '1.sbml'))
#core_model_from_PT.reactions
fulla_model_from_PT.optimize()
#deltag = pd.read_table(os.path.join(modeldir, 'Otauri.COBRA-sbml3.xml'), index_col='')
# Out:
# cobra/io/sbml.py:235 UserWarning: ASCORBATE_c appears as a reactant and product RXN__45__12440
# cobra/io/sbml.py:235 UserWarning: FRUCTOSE__45__6P_c appears as a reactant and product RXN__45__14812__45__FRUCTOSE__45__6P__47____47__FRUCTOSE__45__6P__46__25__46__
# cobra/io/sbml.py:235 UserWarning: PROTON_c appears as a reactant and product _2__46__7__46__1__46__152__45__RXN
# cobra/io/sbml.py:235 UserWarning: PROTON_c appears as a reactant and product RXN__45__17886
# cobra/io/sbml.py:235 UserWarning: PROTON_c appears as a reactant and product RXN__45__10972
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-608a809abb99> in <module>()
#       1 modeldir = '/Users/kuma889/Projects/Boltzmann/Boltz/Ostreococcus/SBML'
#       2 #core_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'Libourel_Otauri_SBMLModel.xml'))
# ----> 3 fulla_model_from_PT = cobra.io.read_sbml_model(os.path.join(modeldir, '1.sbml'))
#       4 #core_model_from_PT.reactions
#       5 fulla_model_from_PT.optimize()
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/cobra/io/sbml3.pyc in read_sbml_model(filename, number, **kwargs)
#     579                 xmlfile.write(outfile, encoding="UTF-8")
#     580             filename = outfile.name
# --> 581         return read_sbml2(filename, **kwargs)
#     582     try:
#     583         return parse_xml_into_model(xml, number=number)
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/cobra/io/sbml.pyc in create_cobra_model_from_sbml_file(sbml_filename, old_sbml, legacy_metabolite, print_time, use_hyphens)
#     349     cobra_model.compartments = compartment_dict
#     350
# --> 351     cobra_model.add_reactions(cobra_reaction_list)
#     352     set_objective(cobra_model, coefficients)
#     353     return cobra_model
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/cobra/core/model.pyc in add_reactions(self, reaction_list)
#     578
#     579         # from cameo ...
# --> 580         self._populate_solver(pruned)
#     581
#     582     def remove_reactions(self, reactions, remove_orphans=False):
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/cobra/core/model.pyc in _populate_solver(self, reaction_list, metabolite_list)
#     750
#     751             forward_variable = self.problem.Variable(
# --> 752                 reaction.id, lb=forward_lb, ub=forward_ub)
#     753             reverse_variable = self.problem.Variable(
#     754                 reaction.reverse_id, lb=reverse_lb, ub=reverse_ub)
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/optlang/symbolics.pyc in __new__(cls, name, **kwargs)
#     130             obj = sympy.Symbol.__new__(cls, str(uuid.uuid1()))
#     131
# --> 132             obj.name = name
#     133             obj._assumptions = FactKB(_assume_rules)
#     134             obj._assumptions._tell('commutative', True)
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/optlang/glpk_interface.pyc in name(self, value)
#     143     def name(self, value):
#     144         if len(value) > 256:
# --> 145             raise ValueError("GLPK does not support ID's longer than 256 characters")
#     146         if getattr(self, 'problem', None) is not None:
#     147             glp_set_col_name(self.problem.problem, glp_find_col(self.problem.problem, self.name), str(value))
#
# ValueError: GLPK does not support ID's longer than 256 characters

# %% [markdown]
# #  Otauri Models from Pathway tools

# %%
import json
import os
import cobra
modeldir = '/Users/kuma889/Projects/Boltzmann/Boltz/Ostreococcus/SBML'
core_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'central_metabolism_ST.sbml'))
#core_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'central_metabolism_ST_COBRA_sbml3.xml'))
core_model.objective= 'RXN__45__1641'
core_model.optimize()
#core_model.metabolites.Triacylglycerols_c
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     336             method = get_real_method(obj, self.print_method)
#     337             if method is not None:
# --> 338                 return method()
#     339             return None
#     340         else:
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/cobra/core/solution.pyc in _repr_html_(self)
#      94                         'value {:.3f}</strong><br>{}'
#      95                         .format(self.objective_value,
# ---> 96                                 self.to_frame()._repr_html_()))
#      97         else:
#      98             html = '<strong><em>{}</em> solution</strong>'.format(self.status)
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\xd7' in position 1414: ordinal not in range(128)
# <Solution 0.000 at 0x11e08cbd0>

# %% [markdown]
# ## conversion from SBML to Boltzmann input files

# %%
import libsbml
r = libsbml.SBMLReader()
d = r.readSBML('modeldir/')
if d.getNumErrors() > 0 :
    print (d.getError(0).getMessage())
else : 
    m = d.getModel()
deltag = pd.read_table('/Users/kuma889/Projects/Boltzmann/Boltz/Ostreococcus/SBML/central_metabolism_dg0.tab', index_col='ID')
deltag
# Out:
# File unreadable.
#                                                                                        Name  \
# ID
# FUMHYDR-RXN                               (<i>S</i>)-malate  &larr;  fumarate + H<sub>2<...
# MALATE-DEH-RXN                            (<i>S</i>)-malate + NAD<sup>+</sup>  &harr;  o...
# 2OXOGLUTARATEDEH-RXN                      2-oxoglutarate + coenzyme A + NAD<sup>+</sup> ...
# ACONITATEHYDR-RXN                         <i>cis</i>-aconitate + H<sub>2</sub>O  &harr; ...
# CITSYN-RXN                                acetyl-CoA + oxaloacetate + H<sub>2</sub>O  &r...
# ACONITATEDEHYDR-RXN                       citrate  &harr;  <i>cis</i>-aconitate + H<sub>...
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN         D-<i>threo</i>-isocitrate + NAD<sup>+</sup>  &...
# SUCCCOASYN-RXN                            succinate + ATP + coenzyme A  &harr;  succinyl...
# RXN-14971                                 succinate<SUB>[in]</SUB> + an electron-transfe...
# RXN0-1132                                 a [pyruvate dehydrogenase E2 protein] <i>N<sup...
# RXN0-1133                                 acetyl-CoA + a [pyruvate dehydrogenase E2 prot...
# RXN0-1134                                 pyruvate + a [pyruvate dehydrogenase E2 protei...
# PSII-RXN                                  2 a plastoquinol<SUB>[membrane]</SUB> + 4 H<SU...
# 1.18.1.2-RXN                              2 a reduced ferredoxin [iron-sulfur] cluster<S...
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN  2 an oxidized plastocyanin<SUB>[in]</SUB> + a ...
# RXN-15479                                 an oxidized plastocyanin<SUB>[in]</SUB> + a re...
# TRANSALDOL-RXN                            D-sedoheptulose 7-phosphate + D-glyceraldehyde...
# 6PGLUCONOLACT-RXN                         6-phospho D-glucono-1,5-lactone + H<sub>2</sub...
# RXN-9952                                  D-gluconate 6-phosphate + NADP<sup>+</sup>  &r...
# GLU6PDEHYDROG-RXN                         D-glucopyranose 6-phosphate + NADP<sup>+</sup>...
# 3PGAREARR-RXN                             2-phospho-D-glycerate  &harr;  3-phospho-D-gly...
# 2PGADEHYDRAT-RXN                          2-phospho-D-glycerate  &harr;  phospho<i>enol<...
# PEPDEPHOS-RXN                             pyruvate + ATP  &larr;  phospho<i>enol</i>pyru...
# RXN-15513                                 2-phospho-D-glycerate  &harr;  3-phospho-D-gly...
# 6PFRUCTPHOS-RXN                           ATP + &beta;-D-fructofuranose 6-phosphate  &ra...
# PGLUCISOM-RXN                             D-glucopyranose 6-phosphate  &harr;  &beta;-D-...
# GAPOXNPHOSPHN-RXN                         D-glyceraldehyde 3-phosphate + NAD<sup>+</sup>...
# PEPSYNTH-RXN                              pyruvate + ATP + H<sub>2</sub>O  &rarr;  phosp...
# 1.1.1.8-RXN                               <i>sn</i>-glycerol 3-phosphate + NAD<sup>+</su...
# RXN-15745                                 <i>sn</i>-glycerol 3-phosphate<SUB>[in]</SUB> ...
# RXN-12383                                 2 a 1,2-diacyl-<i>sn</i>-glycerol  &harr;  a t...
# PHOSPHATIDATE-PHOSPHATASE-RXN             a 1,2-diacyl-<i>sn</i>-glycerol 3-phosphate + ...
# RXN-1381                                  a long-chain acyl-CoA + <i>sn</i>-glycerol 3-p...
# RXN-1623                                  a long-chain acyl-CoA + a 1-acyl-<i>sn</i>-gly...
# RXN-1641                                  a phosphatidylcholine + a 1,2-diacyl-<i>sn</i>...
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN      an acyl-CoA + a 1,2-diacyl-<i>sn</i>-glycerol ...
# RXN-12959                                 CTP + a 1,2-diacyl-<i>sn</i>-glycerol  &rarr; ...
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN     2 3-phospho-D-glycerate + 2 H<SUP>+</SUP>  &la...
# PHOSPHORIBULOKINASE-RXN                   D-ribulose 5-phosphate + ATP  &rarr;  D-ribulo...
# 2TRANSKETO-RXN                            D-erythrose 4-phosphate + D-xylulose 5-phospha...
# RIB5PISOM-RXN                             D-ribose 5-phosphate  &harr;  D-ribulose 5-pho...
# RIBULP3EPIM-RXN                           D-ribulose 5-phosphate  &harr;  D-xylulose 5-p...
# 1TRANSKETO-RXN                            D-sedoheptulose 7-phosphate + D-glyceraldehyde...
# PHOSGLYPHOS-RXN                           3-phospho-D-glycerate + ATP  &harr;  3-phospho...
# TRIOSEPISOMERIZATION-RXN                  D-glyceraldehyde 3-phosphate  &harr;  glyceron...
# F16ALDOLASE-RXN                           fructose 1,6-bisphosphate  &harr;  glycerone p...
# F16BDEPHOS-RXN                            fructose 1,6-bisphosphate + H<sub>2</sub>O  &r...
# 1.2.1.13-RXN                              D-glyceraldehyde 3-phosphate + NADP<sup>+</sup...
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN          D-sedoheptulose-1,7-bisphosphate + H<sub>2</su...
# SEDOBISALDOL-RXN                          glycerone phosphate + D-erythrose 4-phosphate ...
#
#                                                                       Matches  \
# ID
# FUMHYDR-RXN                                                          PWY-5690
# MALATE-DEH-RXN                                                       PWY-5690
# 2OXOGLUTARATEDEH-RXN                                                 PWY-5690
# ACONITATEHYDR-RXN                                                    PWY-5690
# CITSYN-RXN                                                           PWY-5690
# ACONITATEDEHYDR-RXN                                                  PWY-5690
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN                                    PWY-5690
# SUCCCOASYN-RXN                                                       PWY-5690
# RXN-14971                                                            PWY-5690
# RXN0-1132                                                      PYRUVDEHYD-PWY
# RXN0-1133                                                      PYRUVDEHYD-PWY
# RXN0-1134                                                      PYRUVDEHYD-PWY
# PSII-RXN                                                              PWY-101
# 1.18.1.2-RXN                                                          PWY-101
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN                              PWY-101
# RXN-15479                                                             PWY-101
# TRANSALDOL-RXN                                        PENTOSE-P-PWY, PWY-5723
# 6PGLUCONOLACT-RXN                                               PENTOSE-P-PWY
# RXN-9952                                                        PENTOSE-P-PWY
# GLU6PDEHYDROG-RXN                                               PENTOSE-P-PWY
# 3PGAREARR-RXN                                            GLYCOLYSIS, PWY-5723
# 2PGADEHYDRAT-RXN                                         GLYCOLYSIS, PWY-5723
# PEPDEPHOS-RXN                                            GLYCOLYSIS, PWY-5723
# RXN-15513                                                          GLYCOLYSIS
# 6PFRUCTPHOS-RXN                                                    GLYCOLYSIS
# PGLUCISOM-RXN                                                      GLYCOLYSIS
# GAPOXNPHOSPHN-RXN                                                  GLYCOLYSIS
# PEPSYNTH-RXN                                                       GLYCOLYSIS
# 1.1.1.8-RXN                                                          PWY-6118
# RXN-15745                                                            PWY-6118
# RXN-12383                                                        TRIGLSYN-PWY
# PHOSPHATIDATE-PHOSPHATASE-RXN                                    TRIGLSYN-PWY
# RXN-1381                                                         TRIGLSYN-PWY
# RXN-1623                                                         TRIGLSYN-PWY
# RXN-1641                                                         TRIGLSYN-PWY
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN                             TRIGLSYN-PWY
# RXN-12959                                                        TRIGLSYN-PWY
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN                    CALVIN-PWY, PWY-5723
# PHOSPHORIBULOKINASE-RXN                                  CALVIN-PWY, PWY-5723
# 2TRANSKETO-RXN                            CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# RIB5PISOM-RXN                             CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# RIBULP3EPIM-RXN                           CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# 1TRANSKETO-RXN                            CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# PHOSGLYPHOS-RXN                                        CALVIN-PWY, GLYCOLYSIS
# TRIOSEPISOMERIZATION-RXN                               CALVIN-PWY, GLYCOLYSIS
# F16ALDOLASE-RXN                                        CALVIN-PWY, GLYCOLYSIS
# F16BDEPHOS-RXN                                         CALVIN-PWY, GLYCOLYSIS
# 1.2.1.13-RXN                                                       CALVIN-PWY
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN                                   CALVIN-PWY
# SEDOBISALDOL-RXN                                                   CALVIN-PWY
#
#                                           Gibbs-0  Unnamed: 4
# ID
# FUMHYDR-RXN                                 0.613         nan
# MALATE-DEH-RXN                               4.46         nan
# 2OXOGLUTARATEDEH-RXN                        -11.4         nan
# ACONITATEHYDR-RXN                           -3.13         nan
# CITSYN-RXN                                  -10.5         nan
# ACONITATEDEHYDR-RXN                          3.35         nan
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN            1.62         nan
# SUCCCOASYN-RXN                              -1.05         nan
# RXN-14971                                    22.8         nan
# RXN0-1132                                    19.4         nan
# RXN0-1133                                   -20.5         nan
# RXN0-1134                                   -49.9         nan
# PSII-RXN                                      nan         nan
# 1.18.1.2-RXN                                 9.63         nan
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN      nan         nan
# RXN-15479                                     nan         nan
# TRANSALDOL-RXN                              -2.92         nan
# 6PGLUCONOLACT-RXN                           -7.36         nan
# RXN-9952                                    -1.38         nan
# GLU6PDEHYDROG-RXN                           -5.93         nan
# 3PGAREARR-RXN                               -1.32         nan
# 2PGADEHYDRAT-RXN                           -0.187         nan
# PEPDEPHOS-RXN                               -2.23         nan
# RXN-15513                                   -1.32         nan
# 6PFRUCTPHOS-RXN                             -14.5         nan
# PGLUCISOM-RXN                                1.38         nan
# GAPOXNPHOSPHN-RXN                           -15.2         nan
# PEPSYNTH-RXN                                -9.58         nan
# 1.1.1.8-RXN                                  4.15         nan
# RXN-15745                                    12.5         nan
# RXN-12383                                       0         nan
# PHOSPHATIDATE-PHOSPHATASE-RXN               -3.05         nan
# RXN-1381                                      253         nan
# RXN-1623                                      325         nan
# RXN-1641                                        0         nan
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN          325         nan
# RXN-12959                                   -99.5         nan
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN        4.14         nan
# PHOSPHORIBULOKINASE-RXN                     -17.3         nan
# 2TRANSKETO-RXN                               3.96         nan
# RIB5PISOM-RXN                               -6.13         nan
# RIBULP3EPIM-RXN                                 0         nan
# 1TRANSKETO-RXN                               1.23         nan
# PHOSGLYPHOS-RXN                             -7.51         nan
# TRIOSEPISOMERIZATION-RXN                    -1.83         nan
# F16ALDOLASE-RXN                              8.23         nan
# F16BDEPHOS-RXN                               6.89         nan
# 1.2.1.13-RXN                                -16.4         nan
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN             9.71         nan
# SEDOBISALDOL-RXN                            -8.13         nan

# %%
import re
class sbml2boltzmann:
    def __init__( self, sbml, deltag ):
        self.sbml = sbml
        self.deltag = deltag['Gibbs-0'].to_dict()
        self.ordRE = re.compile('__([0-9]+)__')
    def repl( self, matchobj ):
        return chr(int(matchobj.group(1)))
   
    def unmunge( self, sbmlid ):
        return self.ordRE.sub( self.repl, sbmlid)
   
    def get_met_comp( self, speciesId ):
        s = self.sbml.getSpecies(speciesId)
        if s.getCompartment() == 'CCO__45__CYTOSOL':
            return self.unmunge( s.getId() + ':' + s.getCompartment() )
        else:
            return self.unmunge( s.getId()).replace('[',':').rstrip(']')
       
    def write_compartment( self, filename ):
        with open(filename, 'w') as out:
            i = 1
            for comp in self.sbml.getListOfCompartments():
                out.write('{}\t{}\tliters\t0\tV\n'.format(self.unmunge(comp.getId()), float(i)))
                i +=1
    def write_concentrations( self, filename, volume=1.0e-15, conc_units=1.0e-9, default_conc=1.1111111e-01):
        with open(filename, 'w') as out:
            out.write('VOLUME\t{}\n'.format(volume))
            out.write('CONC_UNITS\t{}\n'.format(conc_units))
            for species in self.sbml.getListOfSpecies():
                if species.getBoundaryCondition():
                    boundary="F"
                else :
                    boundary="V"
                out.write('{}\t{}\t{}\n'.format(self.get_met_comp(species.getId()), default_conc, boundary))
   
    def getDeltaG( self, rxnName ):
        if rxnName in self.deltag:
            return self.deltag[rxnName]
        else:
            return 0.0
    def write_reactions( self, filename):
        with open(filename, 'w') as out:
            for rxn in self.sbml.getListOfReactions():
                out.write('REACTION\t{}\n'.format(rxn.getName()))
                out.write('LEFT\t{}\n'.format(' + '.join([self.get_met_comp(sr.getSpecies()) 
                                                         for sr in rxn.getListOfReactants()])))
                out.write('RIGHT\t{}\n'.format(' + '.join([self.get_met_comp(sr.getSpecies()) 
                                                         for sr in rxn.getListOfProducts()])))
                out.write('DGZERO\t{}\n'.format(self.getDeltaG(rxn.getName())))
                out.write('DGZERO_UNITS\t{}\n'.format('KCAL/MOL'))
                out.write('//\n')
                         
s2b = sbml2boltzmann(m, deltag)
#s2b.get_met_comp('M_CPD__45__548')
#s2b.write_compartment('/Users/kuma889/Projects/Ostreococcus/SBML/central_metabolism_dg0_test.cmpts')
s2b.write_concentrations('/Users/kuma889/Projects/Ostreococcus/SBML/central_metabolism_dg0_testt.in')
s2b.write_reactions('/Users/kuma889/Projects/Ostreococcus/SBML/central_metabolism_dg0_rxns.dat')

# %% [markdown]
# ## Centeral Metabolism Rxn for MetaFlux in PT

# %%
import pandas as pd
cm=pd.read_table(os.path.join(modeldir, "central_metabolism_st.tab"), index_col="ID")
cm
with open(os.path.join(modeldir,"central_metabolism.rxn"), "w") as out:
    out.write('\n'.join(cm.index))
cm
# Out:
#                                                                                        Name  \
# ID
# FUMHYDR-RXN                               (<i>S</i>)-malate  &larr;  fumarate + H<sub>2<...
# MALATE-DEH-RXN                            (<i>S</i>)-malate + NAD<sup>+</sup>  &harr;  o...
# 2OXOGLUTARATEDEH-RXN                      2-oxoglutarate + coenzyme A + NAD<sup>+</sup> ...
# ACONITATEHYDR-RXN                         <i>cis</i>-aconitate + H<sub>2</sub>O  &harr; ...
# CITSYN-RXN                                acetyl-CoA + oxaloacetate + H<sub>2</sub>O  &r...
# ACONITATEDEHYDR-RXN                       citrate  &harr;  <i>cis</i>-aconitate + H<sub>...
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN         D-<i>threo</i>-isocitrate + NAD<sup>+</sup>  &...
# SUCCCOASYN-RXN                            succinate + ATP + coenzyme A  &harr;  succinyl...
# RXN-14971                                 succinate<SUB>[in]</SUB> + an electron-transfe...
# RXN0-1132                                 a [pyruvate dehydrogenase E2 protein] <i>N<sup...
# RXN0-1133                                 acetyl-CoA + a [pyruvate dehydrogenase E2 prot...
# RXN0-1134                                 pyruvate + a [pyruvate dehydrogenase E2 protei...
# PSII-RXN                                  2 a plastoquinol<SUB>[membrane]</SUB> + 4 H<SU...
# 1.18.1.2-RXN                              2 a reduced ferredoxin [iron-sulfur] cluster<S...
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN  2 an oxidized plastocyanin<SUB>[in]</SUB> + a ...
# RXN-15479                                 an oxidized plastocyanin<SUB>[in]</SUB> + a re...
# TRANSALDOL-RXN                            D-sedoheptulose 7-phosphate + D-glyceraldehyde...
# 6PGLUCONOLACT-RXN                         6-phospho D-glucono-1,5-lactone + H<sub>2</sub...
# RXN-9952                                  D-gluconate 6-phosphate + NADP<sup>+</sup>  &r...
# GLU6PDEHYDROG-RXN                         D-glucopyranose 6-phosphate + NADP<sup>+</sup>...
# 3PGAREARR-RXN                             2-phospho-D-glycerate  &harr;  3-phospho-D-gly...
# 2PGADEHYDRAT-RXN                          2-phospho-D-glycerate  &harr;  phospho<i>enol<...
# PEPDEPHOS-RXN                             pyruvate + ATP  &larr;  phospho<i>enol</i>pyru...
# RXN-15513                                 2-phospho-D-glycerate  &harr;  3-phospho-D-gly...
# 6PFRUCTPHOS-RXN                           ATP + &beta;-D-fructofuranose 6-phosphate  &ra...
# PGLUCISOM-RXN                             D-glucopyranose 6-phosphate  &harr;  &beta;-D-...
# GAPOXNPHOSPHN-RXN                         D-glyceraldehyde 3-phosphate + NAD<sup>+</sup>...
# PEPSYNTH-RXN                              pyruvate + ATP + H<sub>2</sub>O  &rarr;  phosp...
# 1.1.1.8-RXN                               <i>sn</i>-glycerol 3-phosphate + NAD<sup>+</su...
# RXN-15745                                 <i>sn</i>-glycerol 3-phosphate<SUB>[in]</SUB> ...
# RXN-12383                                 2 a 1,2-diacyl-<i>sn</i>-glycerol  &harr;  a t...
# PHOSPHATIDATE-PHOSPHATASE-RXN             a 1,2-diacyl-<i>sn</i>-glycerol 3-phosphate + ...
# RXN-1381                                  a long-chain acyl-CoA + <i>sn</i>-glycerol 3-p...
# RXN-1623                                  a long-chain acyl-CoA + a 1-acyl-<i>sn</i>-gly...
# RXN-1641                                  a phosphatidylcholine + a 1,2-diacyl-<i>sn</i>...
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN      an acyl-CoA + a 1,2-diacyl-<i>sn</i>-glycerol ...
# RXN-12959                                 CTP + a 1,2-diacyl-<i>sn</i>-glycerol  &rarr; ...
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN     2 3-phospho-D-glycerate + 2 H<SUP>+</SUP>  &la...
# PHOSPHORIBULOKINASE-RXN                   D-ribulose 5-phosphate + ATP  &rarr;  D-ribulo...
# 2TRANSKETO-RXN                            D-erythrose 4-phosphate + D-xylulose 5-phospha...
# RIB5PISOM-RXN                             D-ribose 5-phosphate  &harr;  D-ribulose 5-pho...
# RIBULP3EPIM-RXN                           D-ribulose 5-phosphate  &harr;  D-xylulose 5-p...
# 1TRANSKETO-RXN                            D-sedoheptulose 7-phosphate + D-glyceraldehyde...
# PHOSGLYPHOS-RXN                           3-phospho-D-glycerate + ATP  &harr;  3-phospho...
# TRIOSEPISOMERIZATION-RXN                  D-glyceraldehyde 3-phosphate  &harr;  glyceron...
# F16ALDOLASE-RXN                           fructose 1,6-bisphosphate  &harr;  glycerone p...
# F16BDEPHOS-RXN                            fructose 1,6-bisphosphate + H<sub>2</sub>O  &r...
# 1.2.1.13-RXN                              D-glyceraldehyde 3-phosphate + NADP<sup>+</sup...
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN          D-sedoheptulose-1,7-bisphosphate + H<sub>2</su...
# SEDOBISALDOL-RXN                          glycerone phosphate + D-erythrose 4-phosphate ...
#
#                                                                       Matches  \
# ID
# FUMHYDR-RXN                                                          PWY-5690
# MALATE-DEH-RXN                                                       PWY-5690
# 2OXOGLUTARATEDEH-RXN                                                 PWY-5690
# ACONITATEHYDR-RXN                                                    PWY-5690
# CITSYN-RXN                                                           PWY-5690
# ACONITATEDEHYDR-RXN                                                  PWY-5690
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN                                    PWY-5690
# SUCCCOASYN-RXN                                                       PWY-5690
# RXN-14971                                                            PWY-5690
# RXN0-1132                                                      PYRUVDEHYD-PWY
# RXN0-1133                                                      PYRUVDEHYD-PWY
# RXN0-1134                                                      PYRUVDEHYD-PWY
# PSII-RXN                                                              PWY-101
# 1.18.1.2-RXN                                                          PWY-101
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN                              PWY-101
# RXN-15479                                                             PWY-101
# TRANSALDOL-RXN                                        PENTOSE-P-PWY, PWY-5723
# 6PGLUCONOLACT-RXN                                               PENTOSE-P-PWY
# RXN-9952                                                        PENTOSE-P-PWY
# GLU6PDEHYDROG-RXN                                               PENTOSE-P-PWY
# 3PGAREARR-RXN                                            GLYCOLYSIS, PWY-5723
# 2PGADEHYDRAT-RXN                                         GLYCOLYSIS, PWY-5723
# PEPDEPHOS-RXN                                            GLYCOLYSIS, PWY-5723
# RXN-15513                                                          GLYCOLYSIS
# 6PFRUCTPHOS-RXN                                                    GLYCOLYSIS
# PGLUCISOM-RXN                                                      GLYCOLYSIS
# GAPOXNPHOSPHN-RXN                                                  GLYCOLYSIS
# PEPSYNTH-RXN                                                       GLYCOLYSIS
# 1.1.1.8-RXN                                                          PWY-6118
# RXN-15745                                                            PWY-6118
# RXN-12383                                                        TRIGLSYN-PWY
# PHOSPHATIDATE-PHOSPHATASE-RXN                                    TRIGLSYN-PWY
# RXN-1381                                                         TRIGLSYN-PWY
# RXN-1623                                                         TRIGLSYN-PWY
# RXN-1641                                                         TRIGLSYN-PWY
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN                             TRIGLSYN-PWY
# RXN-12959                                                        TRIGLSYN-PWY
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN                    CALVIN-PWY, PWY-5723
# PHOSPHORIBULOKINASE-RXN                                  CALVIN-PWY, PWY-5723
# 2TRANSKETO-RXN                            CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# RIB5PISOM-RXN                             CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# RIBULP3EPIM-RXN                           CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# 1TRANSKETO-RXN                            CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# PHOSGLYPHOS-RXN                                        CALVIN-PWY, GLYCOLYSIS
# TRIOSEPISOMERIZATION-RXN                               CALVIN-PWY, GLYCOLYSIS
# F16ALDOLASE-RXN                                        CALVIN-PWY, GLYCOLYSIS
# F16BDEPHOS-RXN                                         CALVIN-PWY, GLYCOLYSIS
# 1.2.1.13-RXN                                                       CALVIN-PWY
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN                                   CALVIN-PWY
# SEDOBISALDOL-RXN                                                   CALVIN-PWY
#
#                                           Unnamed: 3
# ID
# FUMHYDR-RXN                                      NaN
# MALATE-DEH-RXN                                   NaN
# 2OXOGLUTARATEDEH-RXN                             NaN
# ACONITATEHYDR-RXN                                NaN
# CITSYN-RXN                                       NaN
# ACONITATEDEHYDR-RXN                              NaN
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN                NaN
# SUCCCOASYN-RXN                                   NaN
# RXN-14971                                        NaN
# RXN0-1132                                        NaN
# RXN0-1133                                        NaN
# RXN0-1134                                        NaN
# PSII-RXN                                         NaN
# 1.18.1.2-RXN                                     NaN
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN         NaN
# RXN-15479                                        NaN
# TRANSALDOL-RXN                                   NaN
# 6PGLUCONOLACT-RXN                                NaN
# RXN-9952                                         NaN
# GLU6PDEHYDROG-RXN                                NaN
# 3PGAREARR-RXN                                    NaN
# 2PGADEHYDRAT-RXN                                 NaN
# PEPDEPHOS-RXN                                    NaN
# RXN-15513                                        NaN
# 6PFRUCTPHOS-RXN                                  NaN
# PGLUCISOM-RXN                                    NaN
# GAPOXNPHOSPHN-RXN                                NaN
# PEPSYNTH-RXN                                     NaN
# 1.1.1.8-RXN                                      NaN
# RXN-15745                                        NaN
# RXN-12383                                        NaN
# PHOSPHATIDATE-PHOSPHATASE-RXN                    NaN
# RXN-1381                                         NaN
# RXN-1623                                         NaN
# RXN-1641                                         NaN
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN             NaN
# RXN-12959                                        NaN
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN            NaN
# PHOSPHORIBULOKINASE-RXN                          NaN
# 2TRANSKETO-RXN                                   NaN
# RIB5PISOM-RXN                                    NaN
# RIBULP3EPIM-RXN                                  NaN
# 1TRANSKETO-RXN                                   NaN
# PHOSGLYPHOS-RXN                                  NaN
# TRIOSEPISOMERIZATION-RXN                         NaN
# F16ALDOLASE-RXN                                  NaN
# F16BDEPHOS-RXN                                   NaN
# 1.2.1.13-RXN                                     NaN
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN                 NaN
# SEDOBISALDOL-RXN                                 NaN

# %%
core_model.metabolites
# Out:
# [<Metabolite SUC_CCO__45__IN at 0x120aa4908>,
#  <Metabolite FUM_CCO__45__IN at 0x120aa4588>,
#  <Metabolite SUC_c at 0x120aa4cc0>,
#  <Metabolite AMP_c at 0x120aa4c18>,
#  <Metabolite PYRUVATE_c at 0x120aa4f98>,
#  <Metabolite D__45__SEDOHEPTULOSE__45__1__45__7__45__P2_c at 0x120aa5320>,
#  <Metabolite D__45__SEDOHEPTULOSE__45__7__45__P_c at 0x120aa56d8>,
#  <Metabolite RIBOSE__45__5P_c at 0x120aa59b0>,
#  <Metabolite D__45__glucopyranose__45__6__45__phosphate_c at 0x120aa5be0>,
#  <Metabolite NADP_c at 0x120aa5e10>,
#  <Metabolite RIBULOSE__45__5P_c at 0x120aad080>,
#  <Metabolite NADPH_c at 0x120aad208>,
#  <Metabolite ERYTHROSE__45__4P_c at 0x120aad518>,
#  <Metabolite XYLULOSE__45__5__45__PHOSPHATE_c at 0x120aad748>,
#  <Metabolite GAP_c at 0x120aada58>,
#  <Metabolite CTP_c at 0x120aadcf8>,
#  <Metabolite CDP_c at 0x120aadf98>,
#  <Metabolite FRUCTOSE__45__6P_c at 0x120ab22b0>,
#  <Metabolite FRUCTOSE__45__16__45__DIPHOSPHATE_c at 0x120ab2668>,
#  <Metabolite ACYL__45__COA_c at 0x120ab2978>,
#  <Metabolite CIT_c at 0x120ab2b00>,
#  <Metabolite ACETYL__45__COA_c at 0x120ab2da0>,
#  <Metabolite Pyruvate__45__dehydrogenase__45__acetylDHlipoyl_c at 0x120ab6320>,
#  <Metabolite Pyruvate__45__dehydrogenase__45__dihydrolipoate_c at 0x120ab6278>,
#  <Metabolite Pyruvate__45__dehydrogenase__45__lipoate_c at 0x120ab6588>,
#  <Metabolite PHOSPHATIDYLCHOLINE_c at 0x120ab65f8>,
#  <Metabolite _2__45__Lysophosphatidylcholines_c at 0x120ab6710>,
#  <Metabolite Long__45__Chain__45__Acyl__45__CoAs_c at 0x120ab67f0>,
#  <Metabolite ACYL__45__SN__45__GLYCEROL__45__3P_c at 0x120ab6908>,
#  <Metabolite L__45__PHOSPHATIDATE_c at 0x120ab6a58>,
#  <Metabolite Pi_c at 0x120ab6ba8>,
#  <Metabolite ETR__45__Quinones_c at 0x120ab6cf8>,
#  <Metabolite GLYCEROL__45__3P_CCO__45__IN at 0x120ab9208>,
#  <Metabolite ETR__45__Quinols_c at 0x120ab9160>,
#  <Metabolite DIHYDROXY__45__ACETONE__45__PHOSPHATE_CCO__45__IN at 0x120ab9588>,
#  <Metabolite GLYCEROL__45__3P_c at 0x120ab94e0>,
#  <Metabolite DIHYDROXY__45__ACETONE__45__PHOSPHATE_c at 0x120ab9908>,
#  <Metabolite CIS__45__ACONITATE_c at 0x120ab9860>,
#  <Metabolite THREO__45__DS__45__ISO__45__CITRATE_c at 0x120ab9ba8>,
#  <Metabolite D__45__6__45__P__45__GLUCONO__45__DELTA__45__LACTONE_c at 0x120ab9eb8>,
#  <Metabolite CPD__45__2961_c at 0x120abc1d0>,
#  <Metabolite ATP_c at 0x120abc4a8>,
#  <Metabolite DPG_c at 0x120abc710>,
#  <Metabolite ADP_c at 0x120abc940>,
#  <Metabolite PHOSPHO__45__ENOL__45__PYRUVATE_c at 0x120abccc0>,
#  <Metabolite _2__45__PG_c at 0x120abcf60>,
#  <Metabolite _2__45__KETOGLUTARATE_c at 0x120abf320>,
#  <Metabolite CO__45__A_c at 0x120abf5c0>,
#  <Metabolite SUC__45__COA_c at 0x120abf860>,
#  <Metabolite Oxidized__45__Plastocyanins_CCO__45__IN at 0x120abfb38>,
#  <Metabolite Plastocyanin__45__Reduced_CCO__45__IN at 0x120abfe10>,
#  <Metabolite Reduced__45__ferredoxins_CCO__45__OUT at 0x120abfd68>,
#  <Metabolite NADP_CCO__45__IN at 0x120ac50b8>,
#  <Metabolite Oxidized__45__ferredoxins_CCO__45__OUT at 0x120ac5160>,
#  <Metabolite NADPH_CCO__45__IN at 0x120ac5588>,
#  <Metabolite Plastoquinols_c at 0x120ac5518>,
#  <Metabolite PROTON_CCO__45__IN at 0x120ac5908>,
#  <Metabolite OXYGEN__45__MOLECULE_CCO__45__IN at 0x120ac5898>,
#  <Metabolite Light_c at 0x120ac5978>,
#  <Metabolite PLASTOQUINONE_c at 0x120ac5c88>,
#  <Metabolite PROTON_CCO__45__OUT at 0x120ac5f60>,
#  <Metabolite WATER_CCO__45__IN at 0x120ac8208>,
#  <Metabolite DIACYLGLYCEROL_c at 0x120ac81d0>,
#  <Metabolite Triacylglycerols_c at 0x120ac8518>,
#  <Metabolite CPD__45__409_c at 0x120ac8828>,
#  <Metabolite G3P_c at 0x120ac8898>,
#  <Metabolite D__45__RIBULOSE__45__15__45__P2_c at 0x120ac8b38>,
#  <Metabolite CARBON__45__DIOXIDE_c at 0x120ac8f98>,
#  <Metabolite NAD_c at 0x120ac8ef0>,
#  <Metabolite PROTON_c at 0x120acc1d0>,
#  <Metabolite OXALACETIC_ACID_c at 0x120acc4e0>,
#  <Metabolite NADH_c at 0x120acc828>,
#  <Metabolite MAL_c at 0x120accb38>,
#  <Metabolite FUM_c at 0x120accdd8>,
#  <Metabolite WATER_c at 0x120ad1160>]

# %%
core_model
# Out:
# <Model temp_xml at 0x11f79edd8>

# %%
core_model.objective= 'ATP_c'
#core_model.metabolites.ATP_c
#core_model.reactions[:12]
#print("Optimizing")
#solution=core_model.optimize()
#central_model=cobra.io.read_sbml_model(os.path.join(modeldir,'central_metabolism.sbml')e
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/cobra/core/model.py in objective(self, value)
#     936             try:
# --> 937                 reactions = self.reactions.get_by_any(value)
#     938             except KeyError:
#
# ~/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/cobra/core/dictlist.py in get_by_any(self, iterable)
#      87             iterable = [iterable]
# ---> 88         return [get_item(item) for item in iterable]
#      89
#
# ~/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/cobra/core/dictlist.py in <listcomp>(.0)
#      87             iterable = [iterable]
# ---> 88         return [get_item(item) for item in iterable]
#      89
#
# ~/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/cobra/core/dictlist.py in get_item(item)
#      79             elif isinstance(item, string_types):
# ---> 80                 return self.get_by_id(item)
#      81             elif item in self:
#
# ~/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/cobra/core/dictlist.py in get_by_id(self, id)
#      53         """return the element with a matching id"""
# ---> 54         return list.__getitem__(self, self._dict[id])
#      55
#
# KeyError: 'ATP_c'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-2d35832447fd> in <module>()
# ----> 1 core_model.objective= 'ATP_c'
#       2 #core_model.metabolites.ATP_c
#       3 #core_model.reactions[:12]
#       4 #print("Optimizing")
#       5 #solution=core_model.optimize()
#
# ~/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/cobra/core/model.py in objective(self, value)
#     937                 reactions = self.reactions.get_by_any(value)
#     938             except KeyError:
# --> 939                 raise ValueError('invalid objective')
#     940             value = {rxn: 1 for rxn in reactions}
#     941         set_objective(self, value, additive=False)
#
# ValueError: invalid objective

# %% [markdown]
# ## Get Chemical Potential

# %%
import pandas as pd
from IPython.display import HTML
import libsbml
#r = str(to_unicode(
#            to_bytes(
#                requests.get('http://bigg.ucsd.edu/static/models/iJO1366.xml').text,
#                'ascii','ignore')))


#d = libsbml.SBMLReader().readSBMLFromString(r)
d = libsbml.SBMLReader().readSBML('/Users/kuma889/Projects/Boltzmann/MENTOS/Core/iJO1366.xml')
iJO1366_sbml= d.getModel()
iJO1366 = cobra.io.read_sbml_model('/Users/kuma889/Projects/Boltzmann/MENTOS/Core/iJO1366.xml')
online_supp = 'http://onlinelibrary.wiley.com/store/10.1038/msb4100155/asset/supinfo/msb4100155-sup-0003.xls?v=1&s=d6fe37a9ffd941ef5bc27013b9fa8868482e2d19'
local_supp = '/Users/kuma889/Projects/Boltzmann/MENTOS/Core/msb4100155-sup-0003.xls'
metG = pd.read_excel(local_supp, 
                     sheetname='compounds').rename(columns=lambda x: x.strip()).set_index('abbreviation')
metG.index = metG.index.str.replace('-','__').str.replace('__C','_C')
ijomets = [m.id for m in iJO1366.metabolites]
umets = pd.DataFrame({'universal_BiGG':[m.id[:-2] for m in iJO1366.metabolites]},index=ijomets)
mu0 = umets.join(other=metG, on='universal_BiGG')['formation delta G (pH 7)' ].replace('Not calculated',np.nan).dropna()
print(len(mu0))
display(HTML(mu0.to_frame().to_html()))

idx = fullS.index.intersection(mu0.index)

deltaG0 = fullS.loc[idx].T.dot(mu0[idx])
deltaG0.to_frame()
# Out:
# 1436
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>formation delta G (pH 7)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10fthf_c</th>
#       <td>-144.2810</td>
#     </tr>
#     <tr>
#       <th>12dgr120_c</th>
#       <td>-157.8860</td>
#     </tr>
#     <tr>
#       <th>12dgr140_c</th>
#       <td>-151.3050</td>
#     </tr>
#     <tr>
#       <th>12dgr141_c</th>
#       <td>-106.6220</td>
#     </tr>
#     <tr>
#       <th>12dgr160_c</th>
#       <td>-144.7230</td>
#     </tr>
#     <tr>
#       <th>12dgr161_c</th>
#       <td>-100.0410</td>
#     </tr>
#     <tr>
#       <th>12dgr180_c</th>
#       <td>-138.1420</td>
#     </tr>
#     <tr>
#       <th>12dgr181_c</th>
#       <td>-93.4598</td>
#     </tr>
#     <tr>
#       <th>12ppd__R_c</th>
#       <td>-79.6929</td>
#     </tr>
#     <tr>
#       <th>12ppd__S_c</th>
#       <td>-79.6929</td>
#     </tr>
#     <tr>
#       <th>13dpg_c</th>
#       <td>-585.8110</td>
#     </tr>
#     <tr>
#       <th>14glucan_c</th>
#       <td>-1006.5000</td>
#     </tr>
#     <tr>
#       <th>15dap_c</th>
#       <td>-4.4171</td>
#     </tr>
#     <tr>
#       <th>1ddecg3p_c</th>
#       <td>-348.7750</td>
#     </tr>
#     <tr>
#       <th>1hdec9eg3p_c</th>
#       <td>-319.8530</td>
#     </tr>
#     <tr>
#       <th>1hdecg3p_c</th>
#       <td>-342.1940</td>
#     </tr>
#     <tr>
#       <th>1odec11eg3p_c</th>
#       <td>-316.5620</td>
#     </tr>
#     <tr>
#       <th>1odecg3p_c</th>
#       <td>-338.9040</td>
#     </tr>
#     <tr>
#       <th>1pyr5c_c</th>
#       <td>-60.2665</td>
#     </tr>
#     <tr>
#       <th>1tdec7eg3p_c</th>
#       <td>-323.1440</td>
#     </tr>
#     <tr>
#       <th>1tdecg3p_c</th>
#       <td>-345.4850</td>
#     </tr>
#     <tr>
#       <th>23dappa_c</th>
#       <td>-89.0161</td>
#     </tr>
#     <tr>
#       <th>23ddhb_c</th>
#       <td>-126.7850</td>
#     </tr>
#     <tr>
#       <th>23dhb_c</th>
#       <td>-131.6250</td>
#     </tr>
#     <tr>
#       <th>23dhba_c</th>
#       <td>-335.8130</td>
#     </tr>
#     <tr>
#       <th>23dhbzs_c</th>
#       <td>-198.7250</td>
#     </tr>
#     <tr>
#       <th>23dhdp_c</th>
#       <td>-134.6010</td>
#     </tr>
#     <tr>
#       <th>23dhmb_c</th>
#       <td>-160.7870</td>
#     </tr>
#     <tr>
#       <th>23dhmp_c</th>
#       <td>-159.1420</td>
#     </tr>
#     <tr>
#       <th>23doguln_c</th>
#       <td>-247.1760</td>
#     </tr>
#     <tr>
#       <th>25aics_c</th>
#       <td>-486.8860</td>
#     </tr>
#     <tr>
#       <th>25dkglcn_c</th>
#       <td>-249.6670</td>
#     </tr>
#     <tr>
#       <th>25drapp_c</th>
#       <td>-326.1570</td>
#     </tr>
#     <tr>
#       <th>26dap__LL_c</th>
#       <td>-163.7430</td>
#     </tr>
#     <tr>
#       <th>26dap__M_c</th>
#       <td>-163.7430</td>
#     </tr>
#     <tr>
#       <th>2agpe120_c</th>
#       <td>-331.8970</td>
#     </tr>
#     <tr>
#       <th>2agpe140_c</th>
#       <td>-328.6060</td>
#     </tr>
#     <tr>
#       <th>2agpe141_c</th>
#       <td>-306.2650</td>
#     </tr>
#     <tr>
#       <th>2agpe160_c</th>
#       <td>-325.3160</td>
#     </tr>
#     <tr>
#       <th>2agpe161_c</th>
#       <td>-302.9740</td>
#     </tr>
#     <tr>
#       <th>2agpe180_c</th>
#       <td>-322.0250</td>
#     </tr>
#     <tr>
#       <th>2agpe181_c</th>
#       <td>-299.6840</td>
#     </tr>
#     <tr>
#       <th>2agpg120_c</th>
#       <td>-403.3110</td>
#     </tr>
#     <tr>
#       <th>2agpg140_c</th>
#       <td>-400.0200</td>
#     </tr>
#     <tr>
#       <th>2agpg141_c</th>
#       <td>-377.6790</td>
#     </tr>
#     <tr>
#       <th>2agpg160_c</th>
#       <td>-396.7300</td>
#     </tr>
#     <tr>
#       <th>2agpg161_c</th>
#       <td>-374.3880</td>
#     </tr>
#     <tr>
#       <th>2agpg180_c</th>
#       <td>-393.4390</td>
#     </tr>
#     <tr>
#       <th>2agpg181_c</th>
#       <td>-371.0980</td>
#     </tr>
#     <tr>
#       <th>2ahbut_c</th>
#       <td>-151.1490</td>
#     </tr>
#     <tr>
#       <th>2amsa_c</th>
#       <td>-114.7020</td>
#     </tr>
#     <tr>
#       <th>2aobut_c</th>
#       <td>-116.2480</td>
#     </tr>
#     <tr>
#       <th>2cpr5p_c</th>
#       <td>-391.5870</td>
#     </tr>
#     <tr>
#       <th>2dda7p_c</th>
#       <td>-467.9060</td>
#     </tr>
#     <tr>
#       <th>2ddecg3p_c</th>
#       <td>-348.7750</td>
#     </tr>
#     <tr>
#       <th>2ddg6p_c</th>
#       <td>-431.6070</td>
#     </tr>
#     <tr>
#       <th>2ddglcn_c</th>
#       <td>-222.2060</td>
#     </tr>
#     <tr>
#       <th>2dh3dgal_c</th>
#       <td>-219.7150</td>
#     </tr>
#     <tr>
#       <th>2dh3dgal6p_c</th>
#       <td>-431.6070</td>
#     </tr>
#     <tr>
#       <th>2dhguln_c</th>
#       <td>-257.6600</td>
#     </tr>
#     <tr>
#       <th>2dhp_c</th>
#       <td>-148.6590</td>
#     </tr>
#     <tr>
#       <th>2dmmq8_c</th>
#       <td>208.4720</td>
#     </tr>
#     <tr>
#       <th>2dmmql8_c</th>
#       <td>184.0690</td>
#     </tr>
#     <tr>
#       <th>2dr1p_c</th>
#       <td>-352.9020</td>
#     </tr>
#     <tr>
#       <th>2dr5p_c</th>
#       <td>-352.9030</td>
#     </tr>
#     <tr>
#       <th>2h3oppan_c</th>
#       <td>-149.8170</td>
#     </tr>
#     <tr>
#       <th>2hdec9eg3p_c</th>
#       <td>-319.8530</td>
#     </tr>
#     <tr>
#       <th>2hdecg3p_c</th>
#       <td>-342.1940</td>
#     </tr>
#     <tr>
#       <th>2ippm_c</th>
#       <td>-142.6780</td>
#     </tr>
#     <tr>
#       <th>2mahmp_c</th>
#       <td>-412.4040</td>
#     </tr>
#     <tr>
#       <th>2mcacn_c</th>
#       <td>-222.6120</td>
#     </tr>
#     <tr>
#       <th>2mcit_c</th>
#       <td>-280.4140</td>
#     </tr>
#     <tr>
#       <th>2me4p_c</th>
#       <td>-365.5040</td>
#     </tr>
#     <tr>
#       <th>2obut_c</th>
#       <td>-110.9280</td>
#     </tr>
#     <tr>
#       <th>2odec11eg3p_c</th>
#       <td>-316.5620</td>
#     </tr>
#     <tr>
#       <th>2odecg3p_c</th>
#       <td>-338.9040</td>
#     </tr>
#     <tr>
#       <th>2ohph_c</th>
#       <td>175.2550</td>
#     </tr>
#     <tr>
#       <th>2ombzl_c</th>
#       <td>150.7870</td>
#     </tr>
#     <tr>
#       <th>2omhmbl_c</th>
#       <td>109.7890</td>
#     </tr>
#     <tr>
#       <th>2ommbl_c</th>
#       <td>149.2050</td>
#     </tr>
#     <tr>
#       <th>2omph_c</th>
#       <td>190.2020</td>
#     </tr>
#     <tr>
#       <th>2oph_c</th>
#       <td>214.6710</td>
#     </tr>
#     <tr>
#       <th>2p4c2me_c</th>
#       <td>-856.9750</td>
#     </tr>
#     <tr>
#       <th>2pg_c</th>
#       <td>-371.1370</td>
#     </tr>
#     <tr>
#       <th>2pglyc_c</th>
#       <td>-334.8390</td>
#     </tr>
#     <tr>
#       <th>2shchc_c</th>
#       <td>-193.5190</td>
#     </tr>
#     <tr>
#       <th>2tdec7eg3p_c</th>
#       <td>-323.1440</td>
#     </tr>
#     <tr>
#       <th>2tdecg3p_c</th>
#       <td>-345.4850</td>
#     </tr>
#     <tr>
#       <th>2tpr3dpcoa_c</th>
#       <td>-1297.0800</td>
#     </tr>
#     <tr>
#       <th>34hpp_c</th>
#       <td>-114.8580</td>
#     </tr>
#     <tr>
#       <th>3c2hmp_c</th>
#       <td>-199.5390</td>
#     </tr>
#     <tr>
#       <th>3c3hmp_c</th>
#       <td>-199.5390</td>
#     </tr>
#     <tr>
#       <th>3c4mop_c</th>
#       <td>-189.0560</td>
#     </tr>
#     <tr>
#       <th>3dhguln_c</th>
#       <td>-260.1500</td>
#     </tr>
#     <tr>
#       <th>3dhgulnp_c</th>
#       <td>-472.0420</td>
#     </tr>
#     <tr>
#       <th>3dhq_c</th>
#       <td>-215.0630</td>
#     </tr>
#     <tr>
#       <th>3dhsk_c</th>
#       <td>-166.8340</td>
#     </tr>
#     <tr>
#       <th>3hbcoa_c</th>
#       <td>-819.2920</td>
#     </tr>
#     <tr>
#       <th>3hcinnm_c</th>
#       <td>-71.3229</td>
#     </tr>
#     <tr>
#       <th>3hdcoa_c</th>
#       <td>-809.4210</td>
#     </tr>
#     <tr>
#       <th>3hddcoa_c</th>
#       <td>-806.1300</td>
#     </tr>
#     <tr>
#       <th>3hhcoa_c</th>
#       <td>-816.0020</td>
#     </tr>
#     <tr>
#       <th>3hhdcoa_c</th>
#       <td>-799.5490</td>
#     </tr>
#     <tr>
#       <th>3hocoa_c</th>
#       <td>-812.7110</td>
#     </tr>
#     <tr>
#       <th>3hodcoa_c</th>
#       <td>-796.2580</td>
#     </tr>
#     <tr>
#       <th>3hpppn_c</th>
#       <td>-87.3972</td>
#     </tr>
#     <tr>
#       <th>3htdcoa_c</th>
#       <td>-802.8390</td>
#     </tr>
#     <tr>
#       <th>3ig3p_c</th>
#       <td>-267.2660</td>
#     </tr>
#     <tr>
#       <th>3mob_c</th>
#       <td>-111.0380</td>
#     </tr>
#     <tr>
#       <th>3mop_c</th>
#       <td>-109.3930</td>
#     </tr>
#     <tr>
#       <th>3odcoa_c</th>
#       <td>-801.4280</td>
#     </tr>
#     <tr>
#       <th>3oddcoa_c</th>
#       <td>-798.1370</td>
#     </tr>
#     <tr>
#       <th>3ohcoa_c</th>
#       <td>-808.0090</td>
#     </tr>
#     <tr>
#       <th>3ohdcoa_c</th>
#       <td>-791.5560</td>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-30d16049d151> in <module>()
#      23 display(HTML(mu0.to_frame().to_html()))
#      24
# ---> 25 idx = fullS.index.intersection(mu0.index)
#      26
#      27 deltaG0 = fullS.loc[idx].T.dot(mu0[idx])
#
# NameError: name 'fullS' is not defined

# %% [markdown]
# # Boltzmann
# ## Pentose phosphate + Glycolysis + TCA cycle + Photosynthesis
# Reactions:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import subprocess
import re
import os
from IPython.core.display import display
pd.set_option('display.max_columns', None,'display.max_rows', None)

#args = ("/Users/kuma889/Projects/Boltzmann/Boltz/05_boltz_bug_fix_4432/boltzmann", "central_metabolism_dg0.in")

popen = subprocess.Popen(args, stdout=subprocess.PIPE)
popen.wait()
output = popen.stdout.read()
print(output)
# Out:
# ----
# NameErrorTraceback (most recent call last)
# <ipython-input-3-26314c68f544> in <module>()
-02	2.736477e-02	3.654322e+01	2.742135e-02	3.646793e+01	3.646660e+01	2.742235e-02	8.205135e+04	8.124967e-06	5.228004e-09	0.000000e+00
# 9997	1.939052e-02	4.037907e+01	1.855444e+01	5.359678e-02	3.185093e-04	1.561368e+03	4.765752e-02	2.087023e+01	1.411467e+01	7.065903e-02	7.074422e-02	1.409767e+01	2.551754e+01	1.954333e-02	2.736477e-02	3.654322e+01	2.742135e-02	3.646793e+01	3.646660e+01	2.742235e-02	4.102567e+04	1.218745e-05	1.045601e-08	0.000000e+00
# 9998	1.939052e-02	4.037907e+01	1.855444e+01	5.359678e-02	3.185093e-04	1.561368e+03	4.765752e-02	2.087023e+01	1.411467e+01	7.065903e-02	7.074422e-02	1.409767e+01	2.551754e+01	1.954333e-02	2.736477e-02	3.654322e+01	2.742135e-02	3.646793e+01	3.646660e+01	2.742235e-02	4.102567e+04	1.218745e-05	1.045601e-08	0.000000e+00
# 9999	1.939562e-02	4.037221e+01	1.855444e+01	5.359678e-02	3.185093e-04	1.561368e+03	4.765752e-02	2.087023e+01	1.407952e+01	7.083588e-02	7.093371e-02	1.406010e+01	2.558364e+01	1.949296e-02	2.736477e-02	3.654322e+01	2.742135e-02	3.646793e+01	3.646660e+01	2.742235e-02	4.102567e+04	1.218745e-05	1.045601e-08	0.000000e+00
# 10000	1.939562e-02	4.037221e+01	1.855444e+01	5.359678e-02	3.185093e-04	1.561368e+03	4.765752e-02	2.087023e+01	1.407952e+01	7.083588e-02	7.093371e-02	1.406010e+01	2.558364e+01	1.949296e-02	2.736477e-02	3.654322e+01	2.742135e-02	3.646793e+01	3.646660e+01	2.742235e-02	4.102568e+04	1.218745e-05	1.045601e-08	0.000000e+00

# %% [markdown]
# ## Regulation
# Notice that in the last reaction (PDH) the line
#
# NREGULATION ACETYL-COA 1.00e-03 20.0
#
# The keyword NREGULATION is for negative regulation using a Hill Function with constant = 6.1e-04 and an exponent of 20.0
# $$Activity = \frac{K^{n}}{K^{n} + X^{n}}$$
#
# where K is the constant similar to the Michaelis constant, n is the exponent that controls the steepness of the Hill function and $X$ is the concentration of the species that regulates the activity. The Hill function is used to update the activity of the enzyme as follows:

# %% [markdown]
# # Analyze Simulation Results for centeral Metabolism
# ## Likelihoods from Deterministic Simulation

# %%
ode_likelihoods_timeseries = pd.read_table('central_metabolism_dg0_rxns_GLy.lklhd',header=1, index_col = 0, quoting=2)
#ode_fwd_likelihoods_timeseries = ode_likelihoods_timeseries.iloc[:,fwd_column_idx]

# %%
# Read boltzmann ODE reaction likelihoods
columns = np.arange(1,56,1)
fwd_column_idx = [x for x in np.arange(0,54,2)]
rev_column_idx = [x for x in np.arange(1,54,2)]
#rev_columns = np.arange(0,55,2)
ode_likelihoods_timeseries = pd.read_table('central_metabolism_dg0_rxns_GLy.lklhd',header=1, index_col = 0, quoting=2)
ode_fwd_likelihoods_timeseries = ode_likelihoods_timeseries.iloc[:,fwd_column_idx]
ode_rev_likelihoods_timeseries = ode_likelihoods_timeseries.iloc[:,rev_column_idx]
ode_fwd_likelihoods_timeseries.columns = [x.split("f_")[-1] for x in ode_fwd_likelihoods_timeseries.columns]
ode_rev_likelihoods_timeseries.columns = [x.split("r_")[-1] for x in ode_rev_likelihoods_timeseries.columns]
fwd_column = ode_likelihoods_timeseries.iloc[:,fwd_column_idx].columns
rev_column = ode_likelihoods_timeseries.iloc[:,rev_column_idx].columns
#column_names = [x.split("f_")[-1] for x in ode_likelihoods.columns]
#ode_likelihoods.columns = column_names

plt.figure()
#ode_likelihoods.iloc[:,rev_column_idx].plot(legend=True,logx=True,figsize=(12, 12))
ode_fwd_likelihoods_timeseries.plot(legend=True,logx=False,figsize=(12, 12))
plt.yscale('symlog')
plt.legend(bbox_to_anchor=(1.02, 0.9),bbox_transform=plt.gcf().transFigure)
np.log10(ode_fwd_likelihoods_timeseries.iloc[-100:]).mean()
# Out:
# ----
# IndexErrorTraceback (most recent call last)
# <ipython-input-15-7d83fe8bbb9d> in <module>()
#       5 #rev_columns = np.arange(0,55,2)
#       6 ode_likelihoods_timeseries = pd.read_table('central_metabolism_dg0_rxns_GLy.lklhd',header=1, index_col = 0, quoting=2)
# ----> 7 ode_fwd_likelihoods_timeseries = ode_likelihoods_timeseries.iloc[:,fwd_column_idx]
#       8 ode_rev_likelihoods_timeseries = ode_likelihoods_timeseries.iloc[:,rev_column_idx]
#       9 ode_fwd_likelihoods_timeseries.columns = [x.split("f_")[-1] for x in ode_fwd_likelihoods_timeseries.columns]
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1365             except (KeyError, IndexError):
#    1366                 pass
# -> 1367             return self._getitem_tuple(key)
#    1368         else:
#    1369             # we by definition only have the 0th axis
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#    1735     def _getitem_tuple(self, tup):
#    1736
# -> 1737         self._has_valid_tuple(tup)
#    1738         try:
#    1739             return self._getitem_lowerdim(tup)
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_tuple(self, key)
#     202             if i >= self.obj.ndim:
#     203                 raise IndexingError('Too many indexers')
# --> 204             if not self._has_valid_type(k, i):
#     205                 raise ValueError("Location based indexing can only have "
#     206                                  "[{types}] types"
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_type(self, key, axis)
#    1672             return self._is_valid_integer(key, axis)
#    1673         elif is_list_like_indexer(key):
# -> 1674             return self._is_valid_list_like(key, axis)
#    1675         return False
#    1676
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/indexing.pyc in _is_valid_list_like(self, key, axis)
#    1729         if (hasattr(arr, '__len__') and len(arr) and
#    1730                 (arr.max() >= l or arr.min() < -l)):
# -> 1731             raise IndexError("positional indexers are out-of-bounds")
#    1732
#    1733         return True
#
# IndexError: positional indexers are out-of-bounds

# %% [markdown]
# ode_likelihoods_steadystate = pd.DataFrame(data = ode_fwd_likelihoods_timeseries.iloc[-20:].mean(),
#                                            index = ode_fwd_likelihoods_timeseries.columns,
#                                           columns =['Forward'])
# ode_likelihoods_steadystate['Reverse'] = ode_rev_likelihoods_timeseries.iloc[-20:].mean()
# ode_likelihoods_steadystate['For-Rev'] = ode_likelihoods_steadystate['Forward'] - ode_likelihoods_steadystate['Reverse']
# ode_likelihoods_steadystate['Rxn Probabilities'] = ode_likelihoods_steadystate['For-Rev']/np.sum(abs(ode_likelihoods_steadystate['For-Rev']))
# ode_likelihoods_steadystate

# %% [markdown]
# ## Likelihoods from Stochastic Simulation
# *The average values aren't correct because they don't consider how much relative time was spent in each configuration*

# %%
# Read boltzmann stochastic reaction likelihoods
from IPython.display import display
fwd_columns = np.arange(3,57,2)
rev_columns = np.arange(4,57,2)
stoch_fwd_likelihoods = pd.read_table('../central_metabolism_dg0_rxns.lklhd',header=1, usecols=fwd_columns,quoting=2)
stoch_rev_likelihoods = pd.read_table('../central_metabolism_dg0_rxns.lklhd',header=1, usecols=rev_columns,quoting=2)

column_names = [x.split("f_")[-1] for x in stoch_fwd_likelihoods.columns]
stoch_fwd_likelihoods.columns = column_names
column_names = [x.split("r_")[-1] for x in stoch_rev_likelihoods.columns]
stoch_rev_likelihoods.columns = column_names

plt.figure();
stoch_fwd_likelihoods['CITSYN__45__RXN'].plot(legend=True,logy=False,logx=True,figsize=(12, 12))
plt.yscale('symlog')
#plt.plot(stoch_likelihoods,legend=True)
# plt.plot(stoch_likelihoods,legend=True,logy=True,figsize=(12, 12))
plt.legend(bbox_to_anchor=(1.02, 0.9),bbox_transform=plt.gcf().transFigure)

display(stoch_fwd_likelihoods.iloc[-10000:-1].mean() - stoch_rev_likelihoods.iloc[-10000:-1].mean())
# Out:
# FUMHYDR__45__RXN                                                  -0.446
# MALATE__45__DEH__45__RXN                                        5.92e-07
# _2OXOGLUTARATEDEH__45__RXN                                        -0.449
# ACONITATEHYDR__45__RXN                                            -0.446
# CITSYN__45__RXN                                                    -0.58
# ACONITATEDEHYDR__45__RXN                                          -0.446
# ISOCITRATE__45__DEHYDROGENASE__45__NAD__43____45__RXN            0.00252
# SUCCCOASYN__45__RXN                                                0.446
# RXN__45__14971                                                     0.271
# RXN0__45__1132                                                         0
# RXN0__45__1133                                                 -1.17e-05
# RXN0__45__1134                                                 -1.61e-09
# PSII__45__RXN                                                   -0.00016
# _1__46__18__46__1__46__2__45__RXN                                   -863
# PLASTOQUINOL__45____45__PLASTOCYANIN__45__REDUCTASE__45__RXN      0.0792
# RXN__45__15479                                                   -0.0453
# TRANSALDOL__45__RXN                                                -10.9
# _6PGLUCONOLACT__45__RXN                                             -342
# RXN__45__9952                                                       -279
# GLU6PDEHYDROG__45__RXN                                              -342
# _3PGAREARR__45__RXN                                                -2.39
# _2PGADEHYDRAT__45__RXN                                              4.84
# PEPDEPHOS__45__RXN                                                  6.06
# RXN__45__15513                                                     -2.39
# _6PFRUCTPHOS__45__RXN                                               -198
# PGLUCISOM__45__RXN                                                   269
# GAPOXNPHOSPHN__45__RXN                                          4.96e+04
# dtype: float64

# %% [markdown]
# ## Read in Flux Values from Stochastic Simulation

# %%
#columns = ["Reaction","Description","Flux","Net Flux"]
columns = [0, 3]
skip = np.arange(0,56,2)
stoch_flux = pd.read_table('1st_model/central_metabolism_dg0_rxns.view', sep='\t',index_col=[0], header=None, 
                           usecols=columns,quoting=2,skiprows = skip)
stoch_flux.columns=["Net Flux"]
stoch_flux['Rxn Probability'] = stoch_flux['Net Flux']/np.sum(abs(stoch_flux['Net Flux'].values))
stoch_flux
# Out:
#                                                     Net Flux  Rxn Probability
# 0
# FUMHYDR__45__RXN                                    4.68e+18           0.0323
# MALATE__45__DEH__45__RXN                            4.68e+18           0.0323
# _2OXOGLUTARATEDEH__45__RXN                          4.68e+18           0.0323
# ACONITATEHYDR__45__RXN                              4.68e+18           0.0323
# PHOSGLYPHOS__45__RXN                                    -324        -2.24e-18
# PHOSGLYPHOS__45__RXN                                     324         2.24e-18
# TRIOSEPISOMERIZATION__45__RXN                           -105        -7.24e-19
# TRIOSEPISOMERIZATION__45__RXN                            105         7.24e-19
# F16ALDOLASE__45__RXN                                      83         5.73e-19
# F16ALDOLASE__45__RXN                                     -83        -5.73e-19
# F16BDEPHOS__45__RXN                                     -237        -1.63e-18
# F16BDEPHOS__45__RXN                                      237         1.63e-18
# _1__46__2__46__1__46__13__45__RXN                   3.77e+03          2.6e-17
# _1__46__2__46__1__46__13__45__RXN                  -3.77e+03         -2.6e-17
# SEDOHEPTULOSE__45__BISPHOSPHATASE__45__RXN                -9        -6.21e-20
# SEDOHEPTULOSE__45__BISPHOSPHATASE__45__RXN                 9         6.21e-20
# SEDOBISALDOL__45__RXN                                    -16         -1.1e-19
# SEDOBISALDOL__45__RXN                                     16          1.1e-19

# %% [markdown]
# ## Analyze Metabolite Levels from Deterministic Simulation

# %%
# Read boltzmann stochastic reaction likelihoods
ode_metabolites = pd.read_table('1st_model/central_metabolism_dg0_rxns.concs',header=0,index_col=0)
column_names = [x.split(":")[0] for x in ode_metabolites.columns]
ode_metabolites.columns = column_names

plt.figure();ode_metabolites.plot(legend=True,logy=True,figsize=(10, 10))
plt.legend(bbox_to_anchor=(1.35, 0.95),bbox_transform=plt.gcf().transFigure)

# %%
ode_metabolites.iloc[-20:].mean()
#ode_metabolites['CO2']
# Out:
# 2-OXOGLUTARATE                                                                   0
# 2-PHOSPHO-D-GLYCERATE                                                     1.66e-07
# 3-PHOSPHO-D-GLYCERATE                                                      4.5e-06
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE                                            0.00201
# 6-PHOSPHO_D-GLUCONO-1,5-LACTONE                                           0.000149
# ACETYL-COA                                                                    1.83
# ADP                                                                        0.00056
# ALPHA-D-RIBOSE_5-PHOSPHATE                                                1.66e-08
# AMP                                                                              0
# AN_ACYL-COA                                                               3.74e-05
# AN_ELECTRON-TRANSFER_QUINOL                                               1.66e-09
# AN_ELECTRON-TRANSFER_QUINONE                                              2.02e-05
# AN_OXIDIZED_FERREDOXIN_[IRON-SULFUR]_CLUSTER                                 0.001
# AN_OXIDIZED_PLASTOCYANIN                                                  1.93e-05
# ATP                                                                         0.0096
# A_1,2-DIACYL-SN-GLYCEROL                                                         0
# A_1,2-DIACYL-SN-GLYCEROL_3-PHOSPHATE                                             0
# A_1-ACYL-SN-GLYCERO-3-PHOSPHOCHOLINE                                         1e-05
# A_1-ACYL-SN-GLYCEROL_3-PHOSPHATE                                                 0
# A_2-ACYLGLYCEROL                                                             1e-05
# A_LONG-CHAIN_ACYL-COA                                                      0.00108
# A_PHOSPHATIDYLCHOLINE                                                        1e-05
# A_PLASTOQUINOL                                                            1.06e-06
# A_PLASTOQUINONE                                                           1.89e-05
# A_REDUCED_FERREDOXIN_[IRON-SULFUR]_CLUSTER                                   0.001
# A_REDUCED_PLASTOCYANIN                                                    1.02e-06
# A_TRIACYL-SN-GLYCEROL                                                            0
# A_[PYRUVATE_DEHYDROGENASE_E2_PROTEIN]_N6-DIHYDROLIPOYL-L-LYSINE                  0
# A_[PYRUVATE_DEHYDROGENASE_E2_PROTEIN]_N6-LIPOYL-L-LYSINE                         0
# A_[PYRUVATE_DEHYDROGENASE_E2_PROTEIN]_N6-S-ACETYLDIHYDROLIPOYL-L-LYSINE      3e-05
# BETA-D-FRUCTOFURANOSE_6-PHOSPHATE                                         2.91e-08
# CDP                                                                       0.000514
# CIS-ACONITATE                                                                    0
# CITRATE                                                                   9.96e-09
# CO2                                                                         0.0001
# COA                                                                         0.0014
# CTP                                                                              0
# D-ERYTHROSE_4-PHOSPHATE                                                   1.48e-07
# D-GLUCONATE_6-PHOSPHATE                                                      0.225
# D-GLUCOPYRANOSE_6-PHOSPHATE                                                  1e-05
# D-GLYCERALDEHYDE_3-PHOSPHATE                                              2.32e-09
# D-RIBULOSE-1,5-BISPHOSPHATE                                                   61.8
# D-RIBULOSE_5-PHOSPHATE                                                    1.94e-05
# D-SEDOHEPTULOSE-1,7-BISPHOSPHATE                                             0.258
# D-THREO-ISOCITRATE                                                               0
# D-XYLULOSE_5-PHOSPHATE                                                     1.6e-07
# FRUCTOSE_1,6-BISPHOSPHATE                                                   0.0122
# FUMARATE                                                                  0.000207
# GLYCEROL_1-PHOSPHATE                                                      2.16e-08
# GLYCERONE_PHOSPHATE                                                       1.42e-06
# H+                                                                        3.74e-09
# HNU                                                                       2.99e-08
# MALATE                                                                    0.000139
# NAD+                                                                        0.0026
# NADH                                                                       8.3e-05
# NADP+                                                                      2.1e-06
# NADPH                                                                      0.00012
# ORTHOPHOSPHATE                                                                0.02
# OXALOACETATE                                                                     0
# OXYGEN                                                                       1e-05
# PHOSPHOENOLPYRUVATE                                                       1.39e-07
# PYRUVATE                                                                  5.47e+03
# SEDOHEPTULOSE_7-PHOSPHATE                                                 3.82e-08
# SUCCINATE                                                                   0.0002
# SUCCINYL-COA                                                              0.000535
# dtype: float64

# %% [markdown]
# ## Analyze Metabolite Levels from Stochastic Simulation

# %%
# Read boltzmann stochastic reaction likelihoods
columns = np.arange(1,57,1)
stoch_metabolites = pd.read_table('1st_model/central_metabolism_dg0_rxns.concs',header=0,index_col=0)

plt.figure();stoch_metabolites.plot(legend=True,logy=True,figsize=(12, 12))
plt.legend(bbox_to_anchor=(1.3, 0.92),bbox_transform=plt.gcf().transFigure)

# %%
stoch_metabolites.iloc[-100:,:].mean()
# Out:
# 2-OXOGLUTARATE                                                                   0
# 2-PHOSPHO-D-GLYCERATE                                                            0
# 3-PHOSPHO-D-GLYCERATE                                                            0
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE                                                  0
# 6-PHOSPHO_D-GLUCONO-1,5-LACTONE                                                  0
# ACETYL-COA                                                                   0.591
# ADP                                                                        0.00056
# ALPHA-D-RIBOSE_5-PHOSPHATE                                                       0
# AMP                                                                              0
# AN_ACYL-COA                                                               3.74e-05
# AN_ELECTRON-TRANSFER_QUINOL                                                      0
# AN_ELECTRON-TRANSFER_QUINONE                                              2.02e-05
# AN_OXIDIZED_FERREDOXIN_[IRON-SULFUR]_CLUSTER                                 0.001
# AN_OXIDIZED_PLASTOCYANIN                                                  2.03e-05
# ATP                                                                         0.0096
# A_1,2-DIACYL-SN-GLYCEROL                                                         0
# A_1,2-DIACYL-SN-GLYCEROL_3-PHOSPHATE                                             0
# A_1-ACYL-SN-GLYCERO-3-PHOSPHOCHOLINE                                         1e-05
# A_1-ACYL-SN-GLYCEROL_3-PHOSPHATE                                                 0
# A_2-ACYLGLYCEROL                                                             1e-05
# A_LONG-CHAIN_ACYL-COA                                                      0.00108
# A_PHOSPHATIDYLCHOLINE                                                        1e-05
# A_PLASTOQUINOL                                                            8.51e-06
# A_PLASTOQUINONE                                                           1.15e-05
# A_REDUCED_FERREDOXIN_[IRON-SULFUR]_CLUSTER                                   0.001
# A_REDUCED_PLASTOCYANIN                                                    6.92e-09
# A_TRIACYL-SN-GLYCEROL                                                            0
# A_[PYRUVATE_DEHYDROGENASE_E2_PROTEIN]_N6-DIHYDROLIPOYL-L-LYSINE                  0
# A_[PYRUVATE_DEHYDROGENASE_E2_PROTEIN]_N6-LIPOYL-L-LYSINE                         0
# A_[PYRUVATE_DEHYDROGENASE_E2_PROTEIN]_N6-S-ACETYLDIHYDROLIPOYL-L-LYSINE      3e-05
#                                                                             ...
# COA                                                                         0.0014
# CTP                                                                              0
# D-ERYTHROSE_4-PHOSPHATE                                                          0
# D-GLUCONATE_6-PHOSPHATE                                                          0
# D-GLUCOPYRANOSE_6-PHOSPHATE                                                      0
# D-GLYCERALDEHYDE_3-PHOSPHATE                                                     0
# D-RIBULOSE-1,5-BISPHOSPHATE                                                      0
# D-RIBULOSE_5-PHOSPHATE                                                           0
# D-SEDOHEPTULOSE-1,7-BISPHOSPHATE                                                 0
# D-THREO-ISOCITRATE                                                               0
# D-XYLULOSE_5-PHOSPHATE                                                           0
# FRUCTOSE_1,6-BISPHOSPHATE                                                        0
# FUMARATE                                                                  0.000645
# GLYCEROL_1-PHOSPHATE                                                             0
# GLYCERONE_PHOSPHATE                                                              0
# H+                                                                        4.61e-06
# HNU                                                                       5.51e-06
# MALATE                                                                    0.000433
# NAD+                                                                        0.0026
# NADH                                                                       8.3e-05
# NADP+                                                                      2.1e-06
# NADPH                                                                      0.00012
# ORTHOPHOSPHATE                                                                0.02
# OXALOACETATE                                                                     0
# OXYGEN                                                                       1e-05
# PHOSPHOENOLPYRUVATE                                                              0
# PYRUVATE                                                                   7.8e-06
# SEDOHEPTULOSE_7-PHOSPHATE                                                        0
# SUCCINATE                                                                 1.87e-06
# SUCCINYL-COA                                                              5.03e-06
# Length: 65, dtype: float64

# %% [markdown]
# ## Compare ODE and Stochastic Metabolite Concentrations

# %%
stoch_metabolites.iloc[-100:,:].mean()/ode_metabolites.iloc[-1:,:].mean()
# Out:
# 2-OXOGLUTARATE                                                             nan
# 2-PHOSPHO-D-GLYCERATE                                                      nan
# 3-PHOSPHO-D-GLYCERATE                                                      nan
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE                                            nan
# 6-PHOSPHO_D-GLUCONO-1,5-LACTONE                                            nan
# ACETYL-COA                                                                   1
# ADP                                                                          1
# ALPHA-D-RIBOSE_5-PHOSPHATE                                                 nan
# AMP                                                                        nan
# AN_ACYL-COA                                                                  1
# AN_ELECTRON-TRANSFER_QUINOL                                                nan
# AN_ELECTRON-TRANSFER_QUINONE                                                 1
# AN_OXIDIZED_FERREDOXIN_[IRON-SULFUR]_CLUSTER                                 1
# AN_OXIDIZED_PLASTOCYANIN                                                     1
# ATP                                                                          1
# A_1,2-DIACYL-SN-GLYCEROL                                                   nan
# A_1,2-DIACYL-SN-GLYCEROL_3-PHOSPHATE                                       nan
# A_1-ACYL-SN-GLYCERO-3-PHOSPHOCHOLINE                                         1
# A_1-ACYL-SN-GLYCEROL_3-PHOSPHATE                                           nan
# A_2-ACYLGLYCEROL                                                             1
# A_LONG-CHAIN_ACYL-COA                                                        1
# A_PHOSPHATIDYLCHOLINE                                                        1
# A_PLASTOQUINOL                                                               1
# A_PLASTOQUINONE                                                              1
# A_REDUCED_FERREDOXIN_[IRON-SULFUR]_CLUSTER                                   1
# A_REDUCED_PLASTOCYANIN                                                    2.08
# A_TRIACYL-SN-GLYCEROL                                                      nan
# A_[PYRUVATE_DEHYDROGENASE_E2_PROTEIN]_N6-DIHYDROLIPOYL-L-LYSINE            nan
# A_[PYRUVATE_DEHYDROGENASE_E2_PROTEIN]_N6-LIPOYL-L-LYSINE                   nan
# A_[PYRUVATE_DEHYDROGENASE_E2_PROTEIN]_N6-S-ACETYLDIHYDROLIPOYL-L-LYSINE      1
#                                                                           ...
# COA                                                                          1
# CTP                                                                        nan
# D-ERYTHROSE_4-PHOSPHATE                                                    nan
# D-GLUCONATE_6-PHOSPHATE                                                    nan
# D-GLUCOPYRANOSE_6-PHOSPHATE                                                nan
# D-GLYCERALDEHYDE_3-PHOSPHATE                                               nan
# D-RIBULOSE-1,5-BISPHOSPHATE                                                nan
# D-RIBULOSE_5-PHOSPHATE                                                     nan
# D-SEDOHEPTULOSE-1,7-BISPHOSPHATE                                           nan
# D-THREO-ISOCITRATE                                                         nan
# D-XYLULOSE_5-PHOSPHATE                                                     nan
# FRUCTOSE_1,6-BISPHOSPHATE                                                  nan
# FUMARATE                                                                     1
# GLYCEROL_1-PHOSPHATE                                                       nan
# GLYCERONE_PHOSPHATE                                                        nan
# H+                                                                           1
# HNU                                                                          1
# MALATE                                                                       1
# NAD+                                                                         1
# NADH                                                                         1
# NADP+                                                                        1
# NADPH                                                                        1
# ORTHOPHOSPHATE                                                               1
# OXALOACETATE                                                               nan
# OXYGEN                                                                       1
# PHOSPHOENOLPYRUVATE                                                        nan
# PYRUVATE                                                                     1
# SEDOHEPTULOSE_7-PHOSPHATE                                                  nan
# SUCCINATE                                                                    1
# SUCCINYL-COA                                                                 1
# Length: 65, dtype: float64

# %% [markdown]
# ## Display Pathway Predictions

# %%
from escher import Builder

reaction_data = (stoch_flux['Net Flux'].to_dict())
#reaction_data = (ode_likelihoods_timeseries.iloc[-1]).to_dict()
#for x in reaction_data.keys():
#  y = x.split("f_")[-1]
#  reaction_data[y] = reaction_data.pop(x)
b = Builder(map_name="e_coli_core.Core metabolism",reaction_data=reaction_data)
b.display_in_notebook(menu='zoom')
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="ejpivulojx"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"ejpivulojx"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
FORt2", "segments": {"11": {"to_node_id": "1577044", "from_node_id": "1576666", "b2": {"y": 4749.209372712298, "x": 1360.0}, "b1": {"y": 4827.353507999329, "x": 1360.0}}, "10": {"to_node_id": "1577046", "from_node_id": "1577045", "b2": null, "b1": null}, "13": {"to_node_id": "1576590", "from_node_id": "1577046", "b2": {"y": 4275.94781629675, "x": 1360.0}, "b1": {"y": 4411.784344889025, "x": 1360.0}}, "12": {"to_node_id": "1577044", "from_node_id": "1576833", "b2": {"y": 4744.773286702694, "x": 1360.0}, "b1": {"y": 4779.244289008981, "x": 1360.0}}, "14": {"to_node_id": "1576811", "from_node_id": "1577046", "b2": {"y": 4422.5658350974745, "x": 1360.0}, "b1": {"y": 4455.769750529243, "x": 1360.0}}, "9": {"to_node_id": "1577045", "from_node_id": "1577044", "b2": null, "b1": null}}, "genes": [{"bigg_id": "b2492", "name": "focB"}, {"bigg_id": "b0904", "name": "focA"}], "reversibility": false, "metabolites": [{"coefficient": -1.0, "bigg_id": "for_e"}, {"coefficient": 1.0, "bigg_id": "h_c"}, {"coefficient": 1.0, "bigg_id": "for_c"}, {"coefficient": -1.0, "bigg_id": "h_e"}], "label_x": 1255.7530517578125, "label_y": 4574.13232421875, "gene_reaction_rule": "b0904 or b2492"}, "1577518": {"name": "Formate transport via diffusion", "bigg_id": "FORti", "segments": {"15": {"to_node_id": "1577047", "from_node_id": "1576590", "b2": {"y": 4263.5, "x": 1460.0}, "b1": {"y": 4145.55, "x": 1460.0}}, "16": {"to_node_id": "1576666", "from_node_id": "1577047", "b2": {"y": 4654.322265625, "x": 1460.0}, "b1": {"y": 4488.7, "x": 1460.0}}}, "genes": [{"bigg_id": "b2492", "name": "focB"}, {"bigg_id": "b0904", "name": "focA"}], "reversibility": false, "metabolites": [{"coefficient": 1.0, "bigg_id": "for_e"}, {"coefficient": -1.0, "bigg_id": "fo

# %% [markdown]
# # Infer Regulated Reactions

# %%
ode_metabolites_steadystate['Expected'] = 1.0e-03

S = pd.read_table('neurospora_pentose_phos.glycolysis.tca.2_no_reg.mat',header=0, index_col = 0, quoting=2)
P = (S>0)
del P['forward reaction']

P = P.astype(np.float64)
#display(R)
product_concentrations = P.multiply(ode_metabolites_steadystate['ODE'],axis=1)
product_concentrations[product_concentrations == 0] = 1
product_concentrations_rxns = pd.DataFrame(data = product_concentrations.T.product(), columns=['ODE'])
expect_product_concentrations = P.multiply(ode_metabolites_steadystate['Expected'],axis=1)
expect_product_concentrations[expect_product_concentrations == 0] = 1
product_concentrations_rxns['Expected'] = (expect_product_concentrations.T).product()

s_regulation = '$\Delta S_{reg}$'
product_concentrations_rxns[s_regulation] = \
    np.log(product_concentrations_rxns['ODE']/product_concentrations_rxns['Expected'])

idx = (ode_likelihoods_steadystate['Reverse'] != 0) & (ode_likelihoods_steadystate['Forward'] != 0) & \
            (product_concentrations_rxns[s_regulation]>1)
#display(product_concentrations_rxns[product_concentrations_rxns[s_regulation]>1])
display(product_concentrations_rxns[idx].sort_values(by=s_regulation))
